# %% [markdown]
# # Machine Learning Links

# %% [markdown]
# [GNN Resources - Twitter thread](https://twitter.com/omarsar0/status/1490276912601653248?s=21)
#
# [Speech and Language Processing - PDF Book](https://web.stanford.edu/~jurafsky/slp3/)
#
# [Mathematics of Machine Learing - Online Book](https://tivadardanka.com/book)
#
# [Netflix recommendations beyond 5 stars Part 1 - Blog Post](https://netflixtechblog.com/netflix-recommendations-beyond-the-5-stars-part-1-55838468f429)
#
# [Netflix Prize and SVD - Paper](http://buzzard.ups.edu/courses/2014spring/420projects/math420-UPS-spring-2014-gower-netflix-SVD.pdf)
#
# [Machine Learning with Docker and Kubernetes - Blog Post](https://towardsdatascience.com/machine-learning-with-docker-and-kubernetes-training-models-cbe33a08c999)
#
# [Deep Learning for coders - Course website](https://course.fast.ai/)
#
# [Open Source Gains and Opportunities - Book](https://simonhoiberg.com/ebooks/open-source-gains-and-opportunities?utm_source=twitter&offer=launch_offer)
#
# [Machine Learning - A Probabilistic Perspective - Book](https://probml.github.io/pml-book/)

# %% [markdown]
# [Time Series Analysis - Twitter Thread](https://twitter.com/abhi1thakur/status/1495360495607549952?s=21)
#
# [Web Development Notes - Blog Post](https://towardsdatascience.com/web-development-notes-from-a-data-scientist-95e4794fb4ab)
#
# [Space Science with Python - Youtube Video](https://youtu.be/CM3To3G4iO4)
#
# [Information Flow in Deep Neural Networks - Paper](https://arxiv.org/abs/2202.06749)
#
# [Architecture of Open Source Applications - Book](https://aosabook.org/en/index.html)
#
# [Deep Learning on Graphs](https://web.njit.edu/~ym329/dlg_book/)
#
# [Contextily - Package](https://contextily.readthedocs.io/en/latest/intro_guide.html)
#
# [Flowcv - Website](https://flowcv.io)
#
# [Simplify Jobs - Websit](https://simplify.jobs)
#
# [Graph Neural Networks in Python](https://towardsdatascience.com/graph-neural-networks-in-python-c310c7c18c83)

# %% [markdown]
# [Recommender Models - Twitter Thread](https://twitter.com/radekosmulski/status/1496862506324672515?s=21)
#
# [Yann Lecun Advanced in AI Research - Blog Post](https://ai.facebook.com/blog/yann-lecun-advances-in-ai-research/)
#
# [What are descriptors? - Blog Post](https://www.blog.pythonlibrary.org/2016/06/10/python-201-what-are-descriptors/)
#
# [Machine Learning with Pytorch and Scikit Learn - Book](https://www.amazon.com/Machine-Learning-PyTorch-Scikit-Learn-scikit-learn-ebook-dp-B09NW48MR1/dp/B09NW48MR1/)
# [From Author Website](https://sebastianraschka.com/blog/2022/ml-pytorch-book.html)
#
# [Variational Autoencoders - Blog post](https://jxmo.io/posts/variational-autoencoders)
#
# [Pytorch Resources - Twitter Thread](https://twitter.com/pyimagesearch/status/1497097301567107072?s=21)
#
# [Deep Dive into Deep Learning Compiler - Book](https://tvm.d2l.ai/)
#
# [Scalene: Python Profiler](https://github.com/plasma-umass/scalene)
#
# [The Shapely value in Machine Learning - Paper](https://arxiv.org/abs/2202.05594)
#
# [Mutable AI: Jupyter to Production - Website](https://mutable.ai/)

# %% [markdown]
# [Generative Python in VSCode - Twitter Thread](https://twitter.com/dynamicwebpaige/status/1497368447029858309?s=21)
#
# [Recsys2020Tutorial: Feature Engineering - Repo](https://github.com/rapidsai/deeplearning/tree/main/RecSys2020Tutorial)
#
# [Devops in Data Science - Blog Post](https://medium.com/@mesanthu/devops-in-data-science-c418a4aed0e0)
#
# [Python Data Science Handbook - Book](https://jakevdp.github.io/PythonDataScienceHandbook/)
#
# [AI in Drug Discovery Conference - Twitter Thread](https://twitter.com/tiezzimatteo/status/1497619889179267081?s=21)
#
# [Mathematics for Machine Learning - Blog Post](https://www.edureka.co/blog/mathematics-for-machine-learning/)
#
# [Mathematics Probability and Statistics - Book](http://bit.ly/3rcOSDZ)
#
# [Alogrithms Every Programmer Should Know - Twitter Thread](https://twitter.com/sumukhmg/status/1497886371469414400?s=21)
#
# [How to Extract Data using Spotify API, Python, Spotipy - Blog Post](https://morioh.com/p/31b8a607b2b0?f=5c21fb01c16e2556b555ab32)

# %% [markdown]
# [Asset2Vec - Blog Post](https://towardsdatascience.com/asset2vec-turning-3d-objects-into-vectors-and-back-8335496b756d)
#
# [Time-Series Forecasting Wrap-Up - Blog Post](https://thesequence.substack.com/p/time-series-forecasting-wrap-up)
#
# [GNN Thru Differential Geometry and Topology - Blog Post](https://bit.ly/3rpOv93)
#
# [Free Data Science Books - Website](https://www.theinsaneapp.com/2020/12/free-data-science-books-pdf.html)
#
# [Analyzing Video using Python, OpenCV and Numpy](https://medium.datadriveninvestor.com/analyzing-video-using-python-opencv-and-numpy-5471cab200c4?sk=c1cc14ea15d5afc428eb572b5a7bc065)
#
# [SHAP: Explain ML Models with Python (Shapely Values) - Blog Post](https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7)
#
# [Reinforcement Learning Course Materials - Repo](https://bit.ly/3B51sHW)
#
# [Non-parametric Regression Methods - Twitter Thread](https://twitter.com/docmilanfar/status/1498195883921330177?s=21)
#
# [Intro to Probability with Python - Notebook](https://bit.ly/2TuNIp3)

# %% [markdown]
# [Fake News Detection with Python](https://morioh.com/p/36782d51dbb8?f=5c21fb01c16e2556b555ab32)
#
# [Open-Source Audio Datasets for ML](https://bit.ly/3omcnby)
#
# [PostGIS for Computer Vision Developers (SQL) - Blog Post](https://towardsdatascience.com/postgis-for-computer-vision-developers-5e703e37ad55)
#
# [Gradient estimators for normalising flows - Paper](https://arxiv.org/abs/2202.01314)
#
# [Numba: Accelerate Python functions - Website](http://numba.pydata.org/)
#
# [Papers With Code - Website](http://paperswithcode.com/)
#
# [Generative Adversarial Networks - Paper](https://arxiv.org/abs/2203.00667)
#
# [Performance Analysis of Activation Functions - Paper](https://arxiv.org/abs/2109.14545)
#
# [Domain Adaptation for Dense Information Retrieval - Youtube Video](https://m.youtube.com/watch?v=xbdLowiQTlk)

# %% [markdown]
# [Leafmap: Geospatial Data w/Python - Blog Post](https://towardsdatascience.com/explore-and-visualize-geospatial-data-using-leafmap-python-package-5bb8aafba83a)
#
# [Star Temporal Classification: Sequence Classification with Partially Labeled Data - Paper](https://arxiv.org/abs/2201.12208)
#
# [14 Patterns for Coding Interview Questions - Blog Post](https://hackernoon.com/14-patterns-to-ace-any-coding-interview-question-c5bb3357f6ed)
#
# [32 Datasets for Practice - Blog Post](https://online.datasciencedojo.com/blogs/data-sets-data-science-skills)
#
# [AI Papers to Read - Blog Post](https://towardsdatascience.com/ai-papers-to-read-in-2022-c6edd4302247)
#
# [Revisiting Deep Learning Models for Tabular Data - Paper](https://arxiv.org/abs/2106.11959)
#
# [Introducing MLOps - Book](https://amzn.to/37u6gdp)
#
# [Fourier Transform - Blog Post](https://blog.revolutionanalytics.com/2014/01/the-fourier-transform-explained-in-one-sentence.html)
#
# [Friendly Introduction to ML Compilers - Blog Post](https://huyenchip.com/2021/09/07/a-friendly-introduction-to-machine-learning-compilers-and-optimizers.html)
#
# [Select Star SQL: Interactive SQL Learninng - Website](http://selectstarsql.com)

# %% [markdown]
# [How Do Vision Transformers Work? - Paper](https://paperswithcode.com/paper/how-do-vision-transformers-work-1)
#
# [250+ ML Projects - Blog Post](https://medium.com/coders-camp/230-machine-learning-projects-with-python-5d0c7abf8265)
#
# [Introduction to Statistical Learning](https://www.statlearning.com/)
#
# [Hidden Markov Model with Neo4j - Blog Post](https://towardsdatascience.com/hidden-markov-model-with-neo4j-dde776f9047b)
#
# [Implementing U-Net Architectures for Semantic Segmentation - Blog Post](https://towardsdatascience.com/semantic-segmentation-of-aerial-imagery-captured-by-a-drone-using-different-u-net-approaches-91e32c92803c)
#
# [Generative Flow Networks - Blog Post](https://yoshuabengio.org/2022/03/05/generative-flow-networks/)
#
# [Lifelong Graph Learning - Paper](https://chenwang.site/lgl/)
#
# [One Voice Detector to Rule Them All - Blog Post](https://thegradient.pub/one-voice-detector-to-rule-them-all/)
#
# [Natural Language Processing with Transformers - Book](https://transformersbook.com/)
#
# [Introduction to Graph Neural Networks - Youtube Video](https://youtu.be/3WXhnQr4ADQ)

# %% [markdown]
# [Grokking: Genralization Beyond Overfitting](https://arxiv.org/abs/2201.02177)
#
# [Automating Excel with Python - Book](https://driscollis.gumroad.com/l/openpyxl)
#
# [Generative Flow Networks - Twitter Thread](https://twitter.com/s_scardapane/status/1501947852276129798?s=21)
#
# [End-to-end Intro to Machine Learning with Linear Regression - Blog Post](https://mdrk.io/introduction-to-machine-learning-using-linear-regression/)
#
# [Overview of Gradient Descent Algorithms - Blog Post](https://ruder.io/optimizing-gradient-descent/)
#
# [The Mathematics of AI - Paper](https://arxiv.org/abs/2203.08890)
#
# [Black Hole Weather Forecasting with Deep Learning - Paper](https://arxiv.org/abs/2102.06242)
#
# [Transformers from Scratch - Blog Post](https://e2eml.school/transformers.html)
#
# [Transformer Architecture: Positional Encoding - Blog Post](https://kazemnejad.com/blog/transformer_architecture_positional_encoding/)
#
# [Softmax for neural networks - Blog Post](https://e2eml.school/softmax.html)

# %% [markdown]
# [Non-parametric Machine Learning - Blog Post](https://lernapparat.de/statistics-deep-learning-nonparametric)
#
# [Deep Learning Object Detection App with R Shiny and Tensorflow - Blog Post](https://towardsdatascience.com/building-a-deep-learning-based-object-detection-app-using-r-shiny-and-tensorflow-5c17e93301d0)
#
# [Modern Convolutional Networks - Repo](https://github.com/Nyandwi/ModernConvNets)
#
# [Math Behind Graph Neural Networks - Blog Post](https://rish-16.github.io/posts/gnn-math/)
#
# [CORDS: Efficient Pytorch - Website](https://cords.readthedocs.io/en/latest/)
#
# [PySpark for Data Processing and Machine Learning - Blog Post](https://www.freecodecamp.org/news/use-pyspark-for-data-processing-and-machine-learning/)
#
# [Machine Learning Zoomcamp - Repo](https://github.com/alexeygrigorev/mlbookcamp-code/tree/master/course-zoomcamp)
#
# [Linear Interpolation for Loss - Twitter Thread](https://twitter.com/lchoshen/status/1505931491402035206?s=21)
#
# [Sequence-to-Sequence Bias - Paper](https://arxiv.org/abs/2203.09397)

# %% [markdown]
# [Half-Inverse Gradients for Physical Deep Learning - Paper](https://arxiv.org/abs/2203.10131)
#
# [API Comparison: SOAP, REST, GraphQL, RPC - Blog Post](https://www.altexsoft.com/blog/soap-vs-rest-vs-graphql-vs-rpc/)
#
# [Machine Learning Demos - Twitter Thread](https://twitter.com/osanseviero/status/1506586677497765888?s=21)
#
# [Introduction to Automatic Differentiation Part 1 - Blog Post](https://mdrk.io/introduction-to-automatic-differentiation/)
#
# [Introduction to Automatic Differentiation Part 2 - Blog Post](https://mdrk.io/introduction-to-automatic-differentiation-part2/)
#
# [Implementing a Transformer from Scratch](https://towardsdatascience.com/7-things-you-didnt-know-about-the-transformer-a70d93ced6b2)
#
# [Gaussian Processes Tutorial - Blog Post](https://peterroelants.github.io/posts/gaussian-process-tutorial/)
#
# [Machine Learning Youtube Courses - Repo](https://github.com/dair-ai/ML-YouTube-Courses)
#
# [Data Science Projects With Python - Twitter Thread](https://twitter.com/pythonwithrune/status/1508762734233632775?s=21&t=Eo9NNOEZqw1G6ms-upFq5w)
#
# [Product Analysis Micro-Certification - Course](https://productschool.teachable.com/p/productanalytics)
#
# [Nine Tools for Machine Learning - Blog Post](https://towardsdatascience.com/nine-tools-i-wish-i-mastered-before-my-phd-in-machine-learning-708c6dcb2fb0)

# %% [markdown]
# [Deep Neural Networks and Tabular Data: A Survey - Paper](https://arxiv.org/pdf/2110.01889.pdf)
#
# [Deep Learning Courses - Wesite](https://deep-learning-drizzle.github.io)
#
# [Error Analysis 101 - Twitter Thread](https://twitter.com/marktenenholtz/status/1509500787189190658?s=21&t=apDPWwBXCuIk0lHn-2vBxA)
#
# [Data Dashboarding Tools: Streamlit, Dash, Shiny, Voila - Blog Post](https://www.datarevenue.com/en-blog/data-dashboarding-streamlit-vs-dash-vs-shiny-vs-voila)
#
# [Joint Embedding Methods - Twitter Thread](https://twitter.com/jiachenai/status/1509675842296852486?s=21&t=5yvjJL7HRcEwNHekKJc8KA)
#
# [Transformers for Software Engineers - Blog Post](https://blog.nelhage.com/post/transformers-for-software-engineers/)
#
# [Topological Graph Neural Networks - Paper](https://openreview.net/pdf?id=oxxUMeFwEHd)

# %% [markdown]
# [Google Data Analyitics - Course](https://www.coursera.org/professional-certificates/google-data-analytics/)
#
# [Microsoft Data Analytics - Website](https://docs.microsoft.com/en-us/learn/certifications/browse/?roles=data-analyst%2Cdata-scientist)
#
# [IBM Data Analytics Certificate - Course](https://www.coursera.org/professional-certificates/ibm-data-analyst/)
#
# [Computer Age Statistical Inference - Book](https://hastie.su.domains/CASI_files/PDF/casi.pdf)
#
# [Blackbox Extension - Chrome Extension](https://chrome.google.com/webstore/detail/blackbox-select-copy-past/mcgbeeipkmelnpldkobichboakdfaeon)
#
# [Leetcode - Website](https://leetcode.com/)
#
# [Tech Interview Handbook - Website](https://www.techinterviewhandbook.org/)
#
# [System Design Primer - Repo](https://github.com/donnemartin/system-design-primer)
#
# [Amazon STAR Method for Behavioural Interviews - Website](https://www.amazon.jobs/en/landing_pages/in-person-interview)
#
# [Know Your Data - Website](https://knowyourdata.withgoogle.com/)
#
# [HackerRank - Website](https://www.hackerrank.com/)
#
# [Kaggle - Website](https://www.kaggle.com/)
#
# [PowerBI - Website](https://powerbi.microsoft.com/)
#
# [Tableau - Website](https://www.tableau.com/)
#
# [Playfair Data - Website](https://playfairdata.com/)
#
# [KDNuggets - Website](https://www.kdnuggets.com/)
#
# [Excel Campus - Website](https://www.excelcampus.com/)

# %% [markdown]
# [Kirk D. Borne Papers](https://dblp.org/search?q=kirk.d.borne:&qp=H1.13:W1.1:F1.4:F2.4:F3.4:F4.3)
#
# [Visual Prompting - Paper](https://arxiv.org/abs/2203.17274)
#
# [Physics meets ML - Paper](https://arxiv.org/abs/2203.16797)
#
# [30 Days of Streamlit - Website](https://share.streamlit.io/streamlit/30days)
#
# [Linked In Profile Tips - Twitter Thread](https://twitter.com/austinbelcak/status/1509879777875931149?s=21&t=bwJsAI7PP5akMOumMAZ-uA)

# %% [markdown]
# ### Document for ML Projects
# - Tech debt log
# - ETL pipeline description
# - Future work ideas
# - Experiment logs
# - List of assumptions
# - Potential risks
# - Changelog

# %% [markdown]
# ### Python Packages
# [Pendulum: Date/time](https://pypi.org/project/pendulum/)
#
# [Cryptography](https://cryptography.io/en/latest/)
#
# [Black: Formatter](https://github.com/psf/black)
#
# [Poetry: Dependencies](https://python-poetry.org/)
#
# [Bokeh:  Web plotting](https://bokeh.org/)
#
# [Bowler: Refactoring](https://github.com/facebookincubator/Bowler)
#
# [Pytest: Testing](https://docs.pytest.org/en/7.1.x/)
#
# [Hydra: Configuration](https://hydra.cc/docs/intro/)
#
# [Click: CLI](https://click.palletsprojects.com/en/8.1.x/)
